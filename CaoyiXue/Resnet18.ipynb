# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
path = "/content/drive/MyDrive/EE541_project/"

# %%
import os
import torch
import pandas as pd
import numpy as np
import torch.nn as nn
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils, datasets
from torch.utils.data import random_split
from functools import partial
from dataclasses import dataclass
from collections import OrderedDict
import torchvision
import torch.optim as optim

# %%
random_seed = 123 # set random seed for reproductivity
torch.manual_seed(random_seed)
torch.cuda.manual_seed(random_seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(random_seed)

# %%
train_root = os.path.join(path, "data/asl/train/")
test_root = os.path.join(path, "data/asl/test/")

# %%
device = (torch.device('cuda') if torch.cuda.is_available()
                  else torch.device('cpu'))
print(f"Training on device {device}.")
# Out:
# Training on device cuda.

# %% [markdown]
# ## Preprocessing nomalization
# ### find the original train data (under the random seed 42) statistics including means and variances of 3 channels. And resize to 3x224x224 for resnet50

# %%
# following code running time is long, so I command it
# dataset = datasets.ImageFolder(root = train_root, transform=transforms.ToTensor())
# train_split = 0.8 # split train and validation as 8:2
# train_size = int(train_split * len(dataset))
# val_size = len(dataset) - train_size
# train_dataset, val_dataset = random_split(dataset, [train_size, val_size],
#                                       generator=torch.manual_seed(random_seed)) 
# imgs = torch.stack([img_t for img_t, _ in train_dataset], dim=3)
# mean = imgs.view(3, -1).mean(dim=1)
# std = imgs.view(3, -1).std(dim=1)
print("means is [0.5190, 0.4991, 0.5139], variances is [0.2283, 0.2557, 0.2639]")
# Out:
# means is [0.5190, 0.4991, 0.5139], variances is [0.2283, 0.2557, 0.2639]

# %%
dataset = datasets.ImageFolder(
    root = train_root, 
    transform = transforms.Compose([transforms.ToTensor(),
                                    transforms.Resize(224),
                                    transforms.Normalize((0.5190, 0.4991, 0.5139),
                                                         (0.2283, 0.2557, 0.2639))])
    )
batch_size = 16 
train_split = 0.8 # split train and validation as 8:2

train_size = int(train_split * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size]) # already set random seed in the beginning
print(f"All data size is {len(dataset)}")
print(f"train size is {train_size}")
print(f"validation size is {val_size}")
# Out:
# All data size is 87000
# train size is 69600
# validation size is 17400

# %%
print(len(dataset.classes[:]))
print(dataset.class_to_idx)
# Out:
# 29
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8, 'J': 9, 'K': 10, 'L': 11, 'M': 12, 'N': 13, 'O': 14, 'P': 15, 'Q': 16, 'R': 17, 'S': 18, 'T': 19, 'U': 20, 'V': 21, 'W': 22, 'X': 23, 'Y': 24, 'Z': 25, 'del': 26, 'nothing': 27, 'space': 28}

# %%
batch_size = 128

model = torchvision.models.resnet18(pretrained=True)
input_num_fc = model.fc.in_features
model.fc = nn.Linear(input_num_fc, 29, bias=True)
path_store_net = path+'resnet.pt'
if os.path.exists(path_store_net):
  print("resnet.pt exists")
  model.load_state_dict(torch.load(path_store_net))
model = model.to(device=device)

optimizer = optim.SGD(model.parameters(), lr = 0.001, momentum=0.9)

loss_fn = nn.CrossEntropyLoss()

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %%
import time
n_epochs = 5
loss_train_list = []
acc_train_list = []

loss_val_list = []
acc_val_list = []
acc_val_max = 0

n_stop = 0

for epoch in range(1, n_epochs+1):
  loss_train = 0.0
  correct = 0
  total = 0
  start_time = time.time()
  print(f"Epoch {epoch} Training start:")
  for batch_i, (imgs, labels) in enumerate(train_loader):
    imgs, labels = imgs.to(device), labels.to(device)
    outputs = model(imgs)

    loss = loss_fn(outputs, labels)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    _, predicted = torch.max(outputs, dim=1)
    total += labels.shape[0]
    correct += int((predicted == labels).sum())
    loss_train += loss.item()
    if (batch_i) % 20 == 0:
      print ('Epoch {:.2f}, Step {}, Loss: {:.4f}'
        .format(epoch, batch_i, loss.item()))
      #torch.save(model.state_dict(), path_store_net)
  
  loss_train_list.append(loss_train/len(train_loader))
  acc_train_list.append(100 * correct/total)
  end_time = time.time()
  print('Duration: {} minutes, Epoch {}, Training loss {:.4f}, Training accuracy {:2.3f}%'
    .format((end_time - start_time)/60 ,epoch,
      loss_train/len(train_loader), 100*correct/total))
  
  loss_val = 0.0
  correct = 0
  total = 0
  with torch.no_grad():
    model.eval()
    for imgs, labels in val_loader:
      imgs, labels = imgs.to(device), labels.to(device)
      outputs = model(imgs)
      _, predicted = torch.max(outputs, dim=1)
      total += labels.shape[0]
      correct += int((predicted == labels).sum())
      loss_val += loss.item()

    acc_val = 100*correct/total
    loss_val_list.append(loss_val/len(val_loader))#loss per batch
    acc_val_list.append(acc_val)
    print('Epoch {}, Validation loss {:.4f}, Validation accuracy {:2.3f}%'
      .format(epoch, loss_val/len(val_loader), acc_val))
    
    if acc_val > acc_val_max:
      acc_val_max = acc_val
      torch.save(model.state_dict(), path+'resnet.pt')
      print('Detect Improvement, Save model')
    else:
      n_stop += 1

  if(n_stop == 2):
    break
    
  model.train()
# Out:
# Epoch 1 Training start:
# Epoch 1, Step 0, Loss: 3.5166
# Epoch 1, Step 20, Loss: 3.0404
# Epoch 1, Step 40, Loss: 2.5532
# Epoch 1, Step 60, Loss: 2.0278
# Epoch 1, Step 80, Loss: 1.5272
# Epoch 1, Step 100, Loss: 1.0668
# Epoch 1, Step 120, Loss: 0.7144
# Epoch 1, Step 140, Loss: 0.6011
# Epoch 1, Step 160, Loss: 0.4705
# Epoch 1, Step 180, Loss: 0.3434
# Epoch 1, Step 200, Loss: 0.3067
# Epoch 1, Step 220, Loss: 0.2595
# Epoch 1, Step 240, Loss: 0.2292
# Epoch 1, Step 260, Loss: 0.1959
# Epoch 1, Step 280, Loss: 0.1342
# Epoch 1, Step 300, Loss: 0.1255
# Epoch 1, Step 320, Loss: 0.1329
# Epoch 1, Step 340, Loss: 0.1281
# Epoch 1, Step 360, Loss: 0.1109
# Epoch 1, Step 380, Loss: 0.0930
# Epoch 1, Step 400, Loss: 0.0773
# Epoch 1, Step 420, Loss: 0.0606
# Epoch 1, Step 440, Loss: 0.0573
# Epoch 1, Step 460, Loss: 0.0574
# Epoch 1, Step 480, Loss: 0.0577
# Epoch 1, Step 500, Loss: 0.0706
# Epoch 1, Step 520, Loss: 0.0590
# Epoch 1, Step 540, Loss: 0.0499
# Duration: 377.1287308533986 minutes, Epoch 1, Training loss 0.5954, Training accuracy 90.687%
# Epoch 1, Validation loss 0.0568, Validation accuracy 99.902%
# Detect Improvement, Save model
# Epoch 2 Training start:
# Epoch 2, Step 0, Loss: 0.0551
# Epoch 2, Step 20, Loss: 0.0397
# Epoch 2, Step 40, Loss: 0.0429
# Epoch 2, Step 60, Loss: 0.0497
# Epoch 2, Step 80, Loss: 0.0296
# Epoch 2, Step 100, Loss: 0.0297
# Epoch 2, Step 120, Loss: 0.0290
# Epoch 2, Step 140, Loss: 0.0316
# Epoch 2, Step 160, Loss: 0.0347
# Epoch 2, Step 180, Loss: 0.0298
# Epoch 2, Step 200, Loss: 0.0309
# Epoch 2, Step 220, Loss: 0.0271
# Epoch 2, Step 240, Loss: 0.0240
# Epoch 2, Step 260, Loss: 0.0288
# Epoch 2, Step 280, Loss: 0.0284
# Epoch 2, Step 300, Loss: 0.0224
# Epoch 2, Step 320, Loss: 0.0244
# Epoch 2, Step 340, Loss: 0.0269
# Epoch 2, Step 360, Loss: 0.0264
# Epoch 2, Step 380, Loss: 0.0414
# Epoch 2, Step 400, Loss: 0.0199
# Epoch 2, Step 420, Loss: 0.0199
# Epoch 2, Step 440, Loss: 0.0226
# Epoch 2, Step 460, Loss: 0.0136
# Epoch 2, Step 480, Loss: 0.0171
# Epoch 2, Step 500, Loss: 0.0181
# Epoch 2, Step 520, Loss: 0.0172
# Epoch 2, Step 540, Loss: 0.0173
# Duration: 6.392208993434906 minutes, Epoch 2, Training loss 0.0289, Training accuracy 99.940%
# Epoch 2, Validation loss 0.0202, Validation accuracy 99.966%
# Detect Improvement, Save model
# Epoch 3 Training start:
# Epoch 3, Step 0, Loss: 0.0172
# Epoch 3, Step 20, Loss: 0.0162
# Epoch 3, Step 40, Loss: 0.0166
# Epoch 3, Step 60, Loss: 0.0131
# Epoch 3, Step 80, Loss: 0.0151
# Epoch 3, Step 100, Loss: 0.0116
# Epoch 3, Step 120, Loss: 0.0144
# Epoch 3, Step 140, Loss: 0.0157
# Epoch 3, Step 160, Loss: 0.0109
# Epoch 3, Step 180, Loss: 0.0150
# Epoch 3, Step 200, Loss: 0.0135
# Epoch 3, Step 220, Loss: 0.0130
# Epoch 3, Step 240, Loss: 0.0124
# Epoch 3, Step 260, Loss: 0.0110
# Epoch 3, Step 280, Loss: 0.0129
# Epoch 3, Step 300, Loss: 0.0092
# Epoch 3, Step 320, Loss: 0.0104
# Epoch 3, Step 340, Loss: 0.0164
# Epoch 3, Step 360, Loss: 0.0115
# Epoch 3, Step 380, Loss: 0.0103
# Epoch 3, Step 400, Loss: 0.0082
# Epoch 3, Step 420, Loss: 0.0107
# Epoch 3, Step 440, Loss: 0.0078
# Epoch 3, Step 460, Loss: 0.0109
# Epoch 3, Step 480, Loss: 0.0156
# Epoch 3, Step 500, Loss: 0.0076
# Epoch 3, Step 520, Loss: 0.0073
# Epoch 3, Step 540, Loss: 0.0095
# Duration: 6.434426951408386 minutes, Epoch 3, Training loss 0.0132, Training accuracy 99.987%
# Epoch 3, Validation loss 0.0088, Validation accuracy 99.983%
# Detect Improvement, Save model
# Epoch 4 Training start:
# Epoch 4, Step 0, Loss: 0.0103
# Epoch 4, Step 20, Loss: 0.0081
# Epoch 4, Step 40, Loss: 0.0082
# Epoch 4, Step 60, Loss: 0.0108
# Epoch 4, Step 80, Loss: 0.0090
# Epoch 4, Step 100, Loss: 0.0080
# Epoch 4, Step 120, Loss: 0.0078
# Epoch 4, Step 140, Loss: 0.0077
# Epoch 4, Step 160, Loss: 0.0086
# Epoch 4, Step 180, Loss: 0.0078
# Epoch 4, Step 200, Loss: 0.0273
# Epoch 4, Step 220, Loss: 0.0087
# Epoch 4, Step 240, Loss: 0.0107
# Epoch 4, Step 260, Loss: 0.0093
# Epoch 4, Step 280, Loss: 0.0076
# Epoch 4, Step 300, Loss: 0.0074
# Epoch 4, Step 320, Loss: 0.0091
# Epoch 4, Step 340, Loss: 0.0093
# Epoch 4, Step 360, Loss: 0.0141
# Epoch 4, Step 380, Loss: 0.0068
# Epoch 4, Step 400, Loss: 0.0151
# Epoch 4, Step 420, Loss: 0.0099
# Epoch 4, Step 440, Loss: 0.0069
# Epoch 4, Step 460, Loss: 0.0082
# Epoch 4, Step 480, Loss: 0.0097
# Epoch 4, Step 500, Loss: 0.0058
# Epoch 4, Step 520, Loss: 0.0057
# Epoch 4, Step 540, Loss: 0.0068
# Duration: 6.401213538646698 minutes, Epoch 4, Training loss 0.0084, Training accuracy 99.993%
# Epoch 4, Validation loss 0.0066, Validation accuracy 99.994%
# Detect Improvement, Save model
# Epoch 5 Training start:
# Epoch 5, Step 0, Loss: 0.0051
# Epoch 5, Step 20, Loss: 0.0065
# Epoch 5, Step 40, Loss: 0.0063
# Epoch 5, Step 60, Loss: 0.0073
# Epoch 5, Step 80, Loss: 0.0059
# Epoch 5, Step 100, Loss: 0.0057
# Epoch 5, Step 120, Loss: 0.0068
# Epoch 5, Step 140, Loss: 0.0053
# Epoch 5, Step 160, Loss: 0.0082
# Epoch 5, Step 180, Loss: 0.0061
# Epoch 5, Step 200, Loss: 0.0047
# Epoch 5, Step 220, Loss: 0.0044
# Epoch 5, Step 240, Loss: 0.0056
# Epoch 5, Step 260, Loss: 0.0062
# Epoch 5, Step 280, Loss: 0.0066
# Epoch 5, Step 300, Loss: 0.0052
# Epoch 5, Step 320, Loss: 0.0046
# Epoch 5, Step 340, Loss: 0.0056
# Epoch 5, Step 360, Loss: 0.0048
# Epoch 5, Step 380, Loss: 0.0076
# Epoch 5, Step 400, Loss: 0.0078
# Epoch 5, Step 420, Loss: 0.0057
# Epoch 5, Step 440, Loss: 0.0062
# Epoch 5, Step 460, Loss: 0.0059
# Epoch 5, Step 480, Loss: 0.0043
# Epoch 5, Step 500, Loss: 0.0072
# Epoch 5, Step 520, Loss: 0.0042
# Epoch 5, Step 540, Loss: 0.0040
# Duration: 6.3561570604642235 minutes, Epoch 5, Training loss 0.0060, Training accuracy 99.997%
# Epoch 5, Validation loss 0.0052, Validation accuracy 100.000%
# Detect Improvement, Save model

# %%
import matplotlib.pyplot as plt
from PIL import Image
def predict(img_path, transform):
    # load the image and return the predicted breed
    img = Image.open(img_path)
    img_tensor = transform(img).to(device).unsqueeze(0)
    model.eval()
    output = model(img_tensor)
    _, index = torch.max(output, 1)
    index = index.cpu()
    plt.imshow(img)
    plt.show()
    return dataset.classes[index]

# %%
transform = transforms.Compose([transforms.ToTensor(),
                                    transforms.Resize(224),
                                    transforms.Normalize((0.5190, 0.4991, 0.5139),
                                                         (0.2283, 0.2557, 0.2639))])
i = 1
for file in os.listdir(test_root):
    path = test_root+file
    print("Image "+str(i)+" start")
    prediction = predict(path,transform)
    true_label = file.split('_')[0]
    if prediction == true_label:
        print(f'That is correct - True Label = {true_label} and Prediction : {prediction}')
    else:
        print(f'That is Wrong - True Label = {true_label} and Prediction : {prediction}. However, {prediction} looks like : ')
        img_path = test_root+prediction+'_test.jpg'
        img = Image.open(img_path)
        plt.imshow(img)
        plt.show()
    print('end')
    i+=1
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
sample = torch.randn(1, 3, 224, 224).to(device=device)
model(sample).size()

# %%
import matplotlib.pyplot as plt

def show_batch(imgs_batched):
    """Show image for a batch of samples."""

    grid = utils.make_grid(imgs_batched)
    plt.imshow(grid.numpy().transpose((1, 2, 0)))
    plt.title('Batch from dataloader')

i_batch = 0
for img, label in train_loader:
    print(i_batch, img.size(), label.size())

    # observe 4th batch and stop.
    if i_batch == 3:
        plt.figure()
        show_batch(img)
        plt.axis('off')
        plt.ioff()
        plt.show()
        break
    i_batch += 1
